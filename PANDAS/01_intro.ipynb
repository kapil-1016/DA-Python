# %% [markdown]
# # PANDAS

# %% [markdown]
# Its a python library.

# %% [markdown]
# Word "PANDAS" is acronym for Panel Data, it has no realtion with animal pandas.

# %% [markdown]
# ### Pandas -> MS-Excel on Steroids!

# %%
print(pd.__version__)
# Out:
# 2.3.3
