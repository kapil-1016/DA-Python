# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Churn_Modelling.csv")

# %%
print(df)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# to get a glimpse of data we use tail and head
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.tail() # last rows
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df.info() #.info() function is the best fun to understand dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# .describe() -> gives statistical info about numerical columns i.e. mean, median, mode, std
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
# printing all the colums
print(df.columns)
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
# sorting data frame based on age.
df = df.sort_values('Age')
print(df.head(30).T)
# Out:
#                       1678      4556         9520             9526      9572  \
# RowNumber             1679      4557         9521             9527      9573
# CustomerId        15569178  15796231     15673180         15665521  15641688
# Surname          Kharlamov   Nwankwo  Onyekaozulu  Chiazagomekpele   Collier
# CreditScore            570       681          727              642       644
# Geography           France    France      Germany          Germany     Spain
# Gender              Female    Female       Female             Male      Male
# Age                     18        18           18               18        18
# Tenure                   4         1            2                5         7
# Balance           82767.42  98894.39      93816.7        111183.53       0.0
# NumOfProducts            1         1            2                2         1
# HasCrCard                1         1            1                0         0
# ...

# %%
#print a specific column
print(df["Gender"].head(10))
# Out:
# 1678    Female
# 4556    Female
# 9520    Female
# 9526      Male
# 9572      Male
# 2021    Female
# 2141      Male
# 2136      Male
# 1619      Male
# 4716      Male
# Name: Gender, dtype: object

# %%
print(df['Balance'].head(10))
# Out:
# 1678     82767.42
# 4556     98894.39
# 9520     93816.70
# 9526    111183.53
# 9572         0.00
# 2021    128743.80
# 2141         0.00
# 2136    133550.67
# 1619    151762.74
# 4716         0.00
# Name: Balance, dtype: float64

# %%
#creating a new colum
df['New Balance']=df['Balance'] + 1000
print(df.head(10))
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 1678       1679    15569178        Kharlamov          570    France  Female
# 4556       4557    15796231          Nwankwo          681    France  Female
# 9520       9521    15673180      Onyekaozulu          727   Germany  Female
# 9526       9527    15665521  Chiazagomekpele          642   Germany    Male
# 9572       9573    15641688          Collier          644     Spain    Male
# 2021       2022    15795519         Vasiliev          716   Germany  Female
# 2141       2142    15758372          Wallace          674    France    Male
# 2136       2137    15621893         Bellucci          727    France    Male
# 1619       1620    15770309         McDonald          656    France    Male
# 4716       4717    15805764         Hallahan          646    France    Male
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.drop(columns=['New Balance'])
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 1678       1679    15569178        Kharlamov          570    France  Female
# 4556       4557    15796231          Nwankwo          681    France  Female
# 9520       9521    15673180      Onyekaozulu          727   Germany  Female
# 9526       9527    15665521  Chiazagomekpele          642   Germany    Male
# 9572       9573    15641688          Collier          644     Spain    Male
# ...         ...         ...              ...          ...       ...     ...
# 3531       3532    15653251           Hickey          408    France  Female
# 3033       3034    15578006              Yao          787    France  Female
# 2458       2459    15813303          Rearick          513     Spain    Male
# 6443       6444    15764927           Rogova          753    France    Male
# 6759       6760    15660878            T'ien          705    France    Male
#
# ...

# %%
df['N Bal'] = df['Balance'] + 10000
print(df.head(10))
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 1678       1679    15569178        Kharlamov          570    France  Female
# 4556       4557    15796231          Nwankwo          681    France  Female
# 9520       9521    15673180      Onyekaozulu          727   Germany  Female
# 9526       9527    15665521  Chiazagomekpele          642   Germany    Male
# 9572       9573    15641688          Collier          644     Spain    Male
# 2021       2022    15795519         Vasiliev          716   Germany  Female
# 2141       2142    15758372          Wallace          674    France    Male
# 2136       2137    15621893         Bellucci          727    France    Male
# 1619       1620    15770309         McDonald          656    France    Male
# 4716       4717    15805764         Hallahan          646    France    Male
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.iloc[0:6 , 8:]
# Out:
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 1678   85767.42              1          1               0         71811.90
# 4556  101894.39              1          1               1          9596.40
# 9520   96816.70              2          1               0        126172.11
# 9526  114183.53              2          0               1         10063.75
# 9572    3000.00              1          0               1         59645.24
# 2021  131743.80              1          0               0        197322.13
#
#       Exited  New Balance      N Bal
# 1678       0     86767.42   95767.42
# 4556       0    102894.39  111894.39
# 9520       0     97816.70  106816.70
# 9526       0    115183.53  124183.53
# 9572       1      4000.00   13000.00
# 2021       0    132743.80  141743.80

# %% [markdown]
# ### Combining Data Frames

# %% [markdown]
# Why?

# %% [markdown]
# In real-world data analysis, data rarely comes from one single clean file.
# You often have multiple related datasets — like pieces of a puzzle — and you must combine them to get the full story.

# %% [markdown]
# an instance

# %% [markdown]
# students.csv → has student names and IDs &
# marks.csv → has student IDs and scores, here common is IDs

# %%
# concat-> it stacks the info either row wise or row wise, merge-> its like sql's join combine df's using common columns.
# new_df = pd.concat([df1, df2])
