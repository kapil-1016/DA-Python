# %% [markdown]
# # PieChart

# %% [markdown]
# Circular chart divided into slices to show percentages of the total.

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
categories = ["Fresheres","Juniors","Seniors","SuperSeniors"]
values = np.array([1000, 700, 300, 150])
colors = ["red","green","blue","pink"]
plt.pie(values, labels=categories, autopct="%1.1f%%",colors=colors,
        explode=[0,0,0,0.2], startangle=90) #autopct => auto-percentage, %% to put % in piechart.
# explode parameter is used to pull out (offset) one or more slices of the pie to make them stand out.
plt.title("CUIET", fontsize=20, color="purple")
plt.show()
