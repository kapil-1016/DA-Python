# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# here matplotlib is a library and pyplot is a module from it.

# %%
x = np.array([2022, 2026, 2030, 2034])
y = np.array([1000, 1500, 2000, 1700])

# %%
plt.plot(x,y) # in the function .plot(x-axis, y-axis)
plt.show()
