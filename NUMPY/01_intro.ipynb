# %% [markdown]
# ## NumPy

# %% [markdown]
# Numerical Python: A powerfull python library for mathematical and numberical calculation in python.

# %% [markdown]
# NumPy can be used to store data of different forms- 1d, 2d, 3d, 4d and so on.

# %% [markdown]
# #### Instalation
# pip install numpy -> import numpy as np

# %%
import numpy as np #given numpy an alias->"np"
# we can check numpy's version with a dunder method-> __version__
print(np.__version__)
# Out:
# 2.3.4

# %%
my_list = [1,2,3,4,5,6]
my_list *= 2 # duplicated my list!!!!!!!
print(my_list)
print(type(my_list))
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]
# <class 'list'>

# %%
array = np.array([1,2,3,4])
print(array)
# Out:
# [1 2 3 4]

# %%
print(type(array))
#ndarray -> n-dimenssional_array
# Out:
# <class 'numpy.ndarray'>

# %%
#to multiply 2 by array's elements
array *= 2
print(array)
# Out:
# [2 4 6 8]
